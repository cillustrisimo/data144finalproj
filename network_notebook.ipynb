# %% [markdown]
# # Network Attributes Notebook
# - The below code calls upon a python file we created to capture the "network effects" of festivals, that is:
#   - We store the code seperately for clarity of the output networks here. But please refer to `film_festival_network.py` for functions being called and our code
#   - We calculate festival and film prestige as a function of FilmRank (pagerank)
#   - We visualize the results of our pagerank graphs to get a sense of centrality, and distributions
# - This outputs of this will be CSVs of festival and film FilmRank as features

# %%
from film_festival_network import runPipeline, loadCSV
import pandas as pd

# %%
festival_runs = loadCSV('data/3_imdb-dataset_festival-runs_long.csv')
film_metadata = loadCSV('data/merged_film_data.csv')
festival_metadata = loadCSV('data/4_festival-library_dataset_imdb-and-survey.csv') 

results = runPipeline(
    festivalRuns=festival_runs,
    filmMetadata=film_metadata,
    festivalMetadata=festival_metadata,
    outputDir='./output_final'
)
# Out:
# ...
# Complete: 100%|██████████████████████████████████████████████| 5/5 [07:13<00:00]
# Pipeline complete! Outputs saved to: output_final
# 7145 films, 3161 festivals processed
# 2 visualizations generated
